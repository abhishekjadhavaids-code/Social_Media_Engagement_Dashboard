# %% [markdown]
# # YouTube Engagement Analytics - Simple Data Analysis
#
# This notebook performs simple exploratory data analysis on YouTube video dataset.

# %%
import pandas as pd
import os

# File path to processed CSV dataset
file_path = '../data/processed/powerbi_latest.csv'

# Check if file exists, otherwise load fallback sample dataset
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print("Dataset loaded successfully!")
else:
    # Simple sample dataset
    data = {
        'title': ['Video A', 'Video B', 'Video C', 'Video D', 'Video E'],
        'views': [100000, 250000, 500000, 1200000, 3000000],
        'likes': [5000, 15000, 35000, 90000, 210000],
        'comments': [400, 1200, 3000, 8000, 18000]
    }
    df = pd.DataFrame(data)
    print("Created sample dataset!")

# Display first 5 rows
df.head()

# %% [markdown]
# ## 2. Basic Dataset Information

# %%
# Total rows and columns
print("Rows and Columns:", df.shape)

# View column names
print("\nColumns in dataset:", df.columns.tolist())

# Check for missing values
print("\nMissing values count:")
print(df.isnull().sum())

# %% [markdown]
# ## 3. Summary Statistics

# %%
# Statistical summary of numerical columns
df.describe()

# %% [markdown]
# ## 4. Calculate Engagement Rate

# %%
# Calculate Engagement Rate percentage
# Formula: ((Likes + Comments) / Views) * 100
df['engagement_rate'] = ((df['likes'] + df['comments']) / df['views']) * 100
df['engagement_rate'] = df['engagement_rate'].round(2)

# Display updated table
df.head()

# %% [markdown]
# ## 5. Find Top 5 Performing Videos

# %%
# Top 5 videos by Views
print("=== TOP 5 MOST VIEWED VIDEOS ===")
top_views = df.sort_values(by='views', ascending=False)
print(top_views[['title', 'views', 'likes', 'engagement_rate']].head(5))

# Top 5 videos by Engagement Rate
print("\n=== TOP 5 HIGHEST ENGAGED VIDEOS ===")
top_engagement = df.sort_values(by='engagement_rate', ascending=False)
print(top_engagement[['title', 'views', 'likes', 'engagement_rate']].head(5))

# %% [markdown]
# ## 6. Save Clean Dataset to CSV

# %%
# Save clean output CSV
output_path = '../data/processed/youtube_engagement_cleaned.csv'
os.makedirs(os.path.dirname(output_path), exist_ok=True)
df.to_csv(output_path, index=False)
print("Dataset saved successfully to:", output_path)
